# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulmoiz0portfolio/3d-furniture-website/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(moiz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_983/2927664796.py in <cell line: 0>()
# ----> 1 print(moiz)
#
# NameError: name 'moiz' is not defined
